# %% [markdown]
# <a href="https://colab.research.google.com/github/annaclarabragato/artigograficos/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import gdown
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('pretendentes doença infectocontagiosa.xlsx')

# %%
df
# Out:
#   Doença infectocontagiosa  Pretendentes Disponíveis
# 0                      Não                     31227
# 1                      Sim                      2771

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_style("whitegrid")
sns.barplot(data=df, x="Pretendentes Disponíveis", y="Doença infectocontagiosa")

plt.savefig('GraficoBarra1.svg')
plt.show()

# %%
df = pd.read_excel('pretendentes disponiveis deficiencia.xlsx')

# %%
df
# Out:
#                         Deficiência  Pretendentes Disponíveis
# 0                   Sem Deficiência                     32132
# 1                Deficiência Física                      1361
# 2  Deficiência Física e Intelectual                       400
# 3           Deficiência Intelectual                       105

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_style("whitegrid")
sns.barplot(data=df, x="Pretendentes Disponíveis", y="Deficiência")
plt.savefig('GraficoBarra2.svg')
plt.show()

# %%
df = pd.read_excel('idades pretendentes procuram.xlsx')

# %%
df
# Out:
#              Idade  Pretendentes Disponíveis
# 0       Até 2 anos                      5854
# 1    De 2 a 4 anos                     10965
# 2    De 4 a 6 anos                     10539
# 3    De 6 a 8 anos                      4521
# 4   De 8 a 10 anos                      1353
# 5  De 10 a 12 anos                       419
# 6  De 12 a 14 anos                       158
# 7  De 14 a 16 anos                        94
# 8    Maior 16 anos                        93

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_style("whitegrid")
sns.barplot(data=df, x="Pretendentes Disponíveis", y="Idade")
plt.savefig('GraficoBarra3.svg')
plt.show()

# %%
df = pd.read_excel('faixa etaria crianças acolhidas.xlsx')

# %%
df
# Out:
#         Fx. Etária  Crianças Acolhidas
# 0       Até 2 anos                3708
# 1    De 2 a 4 anos                2840
# 2    De 4 a 6 anos                2682
# 3    De 6 a 8 anos                2583
# 4   De 8 a 10 anos                2941
# 5  De 10 a 12 anos                3276
# 6  De 12 a 14 anos                3956
# 7  De 14 a 16 anos                4549
# 8    Maior 16 anos                5311

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_style("whitegrid")
sns.barplot(data=df, x="Crianças Acolhidas", y="Fx. Etária")
plt.savefig('GraficoBarra4.svg')
plt.show()

# %%
df = pd.read_excel('disponiveis adoção regiao.xlsx')

# %%
df
# Out:
#          Região  Disponíveis para Adoção
# 0  Centro-Oeste                      308
# 1      Nordeste                      808
# 2         Norte                      174
# 3       Sudeste                     2029
# 4           Sul                     1073

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_style("whitegrid")
sns.barplot(data=df, x="Disponíveis para Adoção", y="Região")
plt.savefig('GraficoBarra5.svg')
plt.show()

# %%
df = pd.read_excel('disponiveis adoção deficiencia.xlsx')

# %%
df
# Out:
#                         Deficiência  Disponíveis para Adoção
# 0                   Sem Deficiência                     3584
# 1           Deficiência Intelectual                      559
# 2  Deficiência Física e Intelectual                      192
# 3                Deficiência Física                       57

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_style("whitegrid")
sns.barplot(data=df, x="Disponíveis para Adoção", y="Deficiência")
plt.savefig('GraficoBarra6.svg')
plt.show()

# %%
df = pd.read_excel('disponiveis adoçao faixa etaria.xlsx')

# %%
df
# Out:
#         Fx. Etária  Disponíveis para Adoção
# 0       Até 2 anos                      397
# 1    De 2 a 4 anos                      304
# 2    De 4 a 6 anos                      340
# 3    De 6 a 8 anos                      335
# 4   De 8 a 10 anos                      406
# 5  De 10 a 12 anos                      521
# 6  De 12 a 14 anos                      630
# 7  De 14 a 16 anos                      723
# 8    Maior 16 anos                      731

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_style("whitegrid")
sns.barplot(data=df, x="Disponíveis para Adoção", y="Fx. Etária")
plt.savefig('GraficoBarra7.svg')
plt.show()

# %%
df = pd.read_excel('4e6f77e9-bc1a-4289-8575-7d43fb8312f1.xlsx')

# %%
df
# Out:
#          Região  Crianças Acolhidas
# 0  Centro-Oeste                2344
# 1      Nordeste                4522
# 2         Norte                1504
# 3       Sudeste               15582
# 4           Sul                7931

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_style("whitegrid")
sns.barplot(data=df, x="Crianças Acolhidas", y="Região")
plt.savefig('GraficoBarra8.svg')
plt.show()
